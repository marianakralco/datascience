# %%
# Importação das bibliotecas utilizadas
import numpy as np 
import pandas as pd
import plotly.express as px

# Para esta análise foram consideradas as bases de produto e transações, 
# pois o esperado é a indicação de produtos ou categorias que gerem maior resultado
product = pd.read_csv('../input/archives/product.csv')
transaction = pd.read_csv('../input/archives/transaction_data.csv')

# %%
product.head()
# Out:
#    PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND            COMMODITY_DESC  \
# 0       25671             2       GROCERY  National                  FRZN ICE
# 1       26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
# 2       26093            69        PASTRY   Private                     BREAD
# 3       26190            69       GROCERY   Private      FRUIT - SHELF STABLE
# 4       26355            69       GROCERY   Private             COOKIES/CONES
#
#             SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION
# 2         BREAD:ITALIAN/FRENCH
# 3                  APPLE SAUCE                50 OZ
# 4            SPECIALTY COOKIES                14 OZ

# %%
# O dataset de produto possui 92 mil linhas e 7 colunas
product.shape
# Out:
# (92353, 7)

# %%
transaction.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2375  26984851472    1     1004906         1         1.39
# 1           2375  26984851472    1     1033142         1         0.82
# 2           2375  26984851472    1     1036325         1         0.99
# 3           2375  26984851472    1     1082185         1         1.21
# 4           2375  26984851472    1     8160430         1         1.50
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0       364        -0.60        1631        1          0.0                0.0
# 1       364         0.00        1631        1          0.0                0.0
# 2       364        -0.30        1631        1          0.0                0.0
# 3       364         0.00        1631        1          0.0                0.0
# 4       364        -0.39        1631        1          0.0                0.0

# %%
# O dataset de transações possui 106 mil linhas e 12 colunas
transaction.shape
# Out:
# (106095, 12)

# %%
# Agregando os datasets para visualizar a tendência dos produtos
data_base = transaction[['household_key', 'DAY', 'PRODUCT_ID', 'QUANTITY', 'SALES_VALUE']] \
    .merge(product[['PRODUCT_ID', 'COMMODITY_DESC', 'SUB_COMMODITY_DESC']], on='PRODUCT_ID')

data_base.head()
# Out:
#    household_key  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE COMMODITY_DESC  \
# 0           2375    1     1004906         1         1.39       POTATOES
# 1           1929    4     1004906         1         1.39       POTATOES
# 2            568    4     1004906         1         1.39       POTATOES
# 3            887    5     1004906         1         1.39       POTATOES
# 4            175    7     1004906         1         1.99       POTATOES
#
#            SUB_COMMODITY_DESC
# 0  POTATOES RUSSET (BULK&BAG)
# 1  POTATOES RUSSET (BULK&BAG)
# 2  POTATOES RUSSET (BULK&BAG)
# 3  POTATOES RUSSET (BULK&BAG)
# 4  POTATOES RUSSET (BULK&BAG)

# %%
# Excluindo linhas vazias da coluna COMMODITY_DESC, e a categoria COUPON/MISC ITEMS,
# pois a mesma possui uma grande variação de produtos genéricos
data_base = data_base [~data_base ['COMMODITY_DESC'].isin(['',' ','COUPON/MISC ITEMS'])] 

daily_sales = data_base.groupby(['COMMODITY_DESC', 'DAY']).agg(
    {'SALES_VALUE': 'sum', 'QUANTITY': 'sum', 'household_key': pd.Series.nunique}) \
    .reset_index()

daily_sales.head()
# Out:
#     COMMODITY_DESC  DAY  SALES_VALUE  QUANTITY  household_key
# 0  (CORP USE ONLY)   13         0.95         1              1
# 1  (CORP USE ONLY)   48         1.84         2              1
# 2  (CORP USE ONLY)   51         1.06         1              1
# 3  (CORP USE ONLY)   68         2.34         1              1
# 4  (CORP USE ONLY)   71         4.00         4              1

# %%
# Dataframe para visualizar os valores totais de venda por categoria
sales = daily_sales[['COMMODITY_DESC', 'SALES_VALUE']] \
    .groupby(['COMMODITY_DESC']).sum().reset_index()

# Para melhor visualização nos gráficos serão consideradas as 10 primeiras categorias
sales = sales[sales['COMMODITY_DESC'] != ''].sort_values(by='SALES_VALUE', ascending=False)[:10] \
    .sort_values(by='SALES_VALUE')


fig = px.bar(x=sales.SALES_VALUE,
             y=sales.COMMODITY_DESC,
             labels={
                 'y': 'Categoria',
                 'x': 'Valor em vendas'
             },
             title='Valor de vendas por Categoria',
             template='simple_white')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="d6debcde-55fc-4f88-91a8-34b7c0ee44d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6debcde-55fc-4f88-91a8-34b7c0ee44d6")) {                    Plotly.newPlot(                        "d6debcde-55fc-4f88-91a8-34b7c0ee44d6",                        [{"alignmentgroup":"True","hovertemplate":"Valor em vendas=%{x}<br>Categoria=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[4744.35,5973.15,6098.77,6332.01,6467.63,7011.22,7574.1900000000005,7629.62,14486.77,14955.710000000001],"xaxis":"x","y":["DELI MEATS","FROZEN PIZZA","BAKED BREAD/BUNS/ROLLS","FRZN MEAT/MEAT DINNERS","BAG SNACKS","BEERS/ALES","FLUID MILK PRODUCTS","CHEESE","SOFT DRINKS","BEEF"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888 ...

# %% [markdown]
# A Categoria BEEF é a principal em termos de venda, seguida de SOFT DRINKS.

# %%
# Dataframe para visualizar as quantidades de vendas por categoria
quantity = daily_sales[['COMMODITY_DESC', 'QUANTITY']] \
    .groupby(['COMMODITY_DESC']).sum().reset_index()

# Para melhor visualização nos gráficos serão consideradas as 10 primeiras categorias
quantity = quantity[quantity['COMMODITY_DESC'] != ''].sort_values(by='QUANTITY', ascending=False)[:10] \
    .sort_values(by='QUANTITY')


fig = px.bar(x=quantity.QUANTITY,
             y=quantity.COMMODITY_DESC,
             labels={
                 'y': 'Categoria',
                 'x': 'Quantidade'
             },
             title='Quantidades por Categoria',
             template='simple_white')
fig.show()
# Out:
# <div>                            <div id="28396009-008a-4a61-8609-0dbd4193f8ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28396009-008a-4a61-8609-0dbd4193f8ed")) {                    Plotly.newPlot(                        "28396009-008a-4a61-8609-0dbd4193f8ed",                        [{"alignmentgroup":"True","hovertemplate":"Quantidade=%{x}<br>Categoria=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[2819,2924,3088,3126,3149,3463,3575,4152,4205,6881],"xaxis":"x","y":["SOUP","BEEF","CANDY - CHECKLANE","YOGURT","FRZN MEAT/MEAT DINNERS","BAG SNACKS","CHEESE","FLUID MILK PRODUCTS","BAKED BREAD/BUNS/ROLLS","SOFT DRINKS"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"h ...

# %% [markdown]
# Analisando as quantidades, BEEF já não aparece nas primeiras posições, enquanto SOFT DRINK continua sendo a principal categoria de consumo.

# %%
list_sales = sales['COMMODITY_DESC']

top10_sales = daily_sales[daily_sales['COMMODITY_DESC'] \
                               .isin(list_sales)] \
                                [['COMMODITY_DESC', 'SALES_VALUE', 'DAY']] \
                               .groupby(['COMMODITY_DESC','DAY']).sum().reset_index()




fig = px.box(sales, 
              x = top10_sales.COMMODITY_DESC, 
              y = top10_sales.SALES_VALUE,
             color = top10_sales.COMMODITY_DESC,
             title = 'Distribuição de Vendas por Categoria',
             template = 'simple_white')
fig.show()
# Out:
# <div>                            <div id="d2832b64-5c4f-48ef-85c0-ab413178f75b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2832b64-5c4f-48ef-85c0-ab413178f75b")) {                    Plotly.newPlot(                        "d2832b64-5c4f-48ef-85c0-ab413178f75b",                        [{"alignmentgroup":"True","hovertemplate":"color=BAG SNACKS<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"BAG SNACKS","marker":{"color":"#1F77B4"},"name":"BAG SNACKS","notched":false,"offsetgroup":"BAG SNACKS","orientation":"v","showlegend":true,"x":["BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS","BAG SNACKS"],"x0":" ","xaxis":"x","y":[10.51,3.0,41.75,23.57,12.47,17.150000000000002,45.18,33.3,12.27,42.21,42.5,51.94,29.19,31.56,29.3,26.74,35.99,36.44,83.67,29.32,38.93,12.780000000000001,17.28,62.480000000000004,96.46000000000001,53.15,32.92,28.73,63.04,45.57,57.48,70.87,83.61,70.99,65.92,46.67,44.81,40.72,76.15,80.37,43.9,54.92,52.44,55.93,50.35,75.10000000000001,124.66,70.57,94.33,67.46,78.56,149.04,138.19,96.67999999999999,87.44,90.16,134.14,65.39,105.48,142.72,86.7,116.51,94.42,103.07,131.72,158.26,153.84,212.4,183.09,81.29,113.13,84.45,107.95,206.92000000000002,240.1,108.84,184.72,118.92,149.69,163.12,164.04],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"color=BAKED BREAD/BUNS/ROLLS<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"BAKED BREAD/BUNS/ROLLS","marker":{"color":"#FF7F0E"},"name":"BAKED BREAD/BUNS/ROLLS","notched":false,"offsetgroup":"BAKED BREAD/BUNS/ROLLS","orientation":"v","showlegend":true,"x":["BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED BREAD/BUNS/ROLLS","BAKED B ...

# %% [markdown]
# A categoria BEEF tem a maior variação, com vários outliers puxando o valor médio, SOFT DRINKS também apresenta uma grande variação.

# %%
sales_agg = data_base.groupby(['COMMODITY_DESC']) \
            .agg({'SALES_VALUE':'sum', 'QUANTITY':'sum', 'household_key':pd.Series.nunique}) \
            .rename(columns = {'household_key':'HOUSEHOLDS'}) \
            .reset_index()

fig = px.scatter(sales_agg, 
                 x='QUANTITY', 
                 y='SALES_VALUE',
                 size='HOUSEHOLDS', 
                 color='COMMODITY_DESC',
                 hover_name='COMMODITY_DESC',
                 size_max=60,
                 title = 'Valor de Venda, Quantidade e Clientes por Categoria',
                 template = 'simple_white')
fig.update_layout(showlegend=False)
fig.add_annotation(text='Os tamanhos das bolhas representam o número de famílias que compram o produto',
                  xref='paper', yref='paper',
                  x=-0.02, y=1.11, showarrow=False)
fig.show()
# Out:
# <div>                            <div id="98f4c4d2-db33-4240-93ae-bbaed4e12d18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98f4c4d2-db33-4240-93ae-bbaed4e12d18")) {                    Plotly.newPlot(                        "98f4c4d2-db33-4240-93ae-bbaed4e12d18",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>COMMODITY_DESC=(CORP USE ONLY)<br>QUANTITY=%{x}<br>SALES_VALUE=%{y}<br>HOUSEHOLDS=%{marker.size}<extra></extra>","hovertext":["(CORP USE ONLY)"],"legendgroup":"(CORP USE ONLY)","marker":{"color":"#1F77B4","size":[6],"sizemode":"area","sizeref":0.27305555555555555,"symbol":"circle"},"mode":"markers","name":"(CORP USE ONLY)","orientation":"v","showlegend":true,"x":[10],"xaxis":"x","y":[11.51],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>COMMODITY_DESC=ADULT INCONTINENCE<br>QUANTITY=%{x}<br>SALES_VALUE=%{y}<br>HOUSEHOLDS=%{marker.size}<extra></extra>","hovertext":["ADULT INCONTINENCE"],"legendgroup":"ADULT INCONTINENCE","marker":{"color":"#FF7F0E","size":[10],"sizemode":"area","sizeref":0.27305555555555555,"symbol":"circle"},"mode":"markers","name":"ADULT INCONTINENCE","orientation":"v","showlegend":true,"x":[15],"xaxis":"x","y":[117.33],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>COMMODITY_DESC=AIR CARE<br>QUANTITY=%{x}<br>SALES_VALUE=%{y}<br>HOUSEHOLDS=%{marker.size}<extra></extra>","hovertext":["AIR CARE"],"legendgroup":"AIR CARE","marker":{"color":"#2CA02C","size":[126],"sizemode":"area","sizeref":0.27305555555555555,"symbol":"circle"},"mode":"markers","name":"AIR CARE","orientation":"v","showlegend":true,"x":[289],"xaxis":"x","y":[690.4200000000001],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>COMMODITY_DESC=ANALGESICS<br>QUANTITY=%{x}<br>SALES_VALUE=%{y}<br>HOUSEHOLDS=%{marker.size}<extra></extra>","hovertext":["ANALGESICS"],"legendgroup":"ANALGESICS","marker":{"color":"#D62728","size":[125],"sizemode":"area","sizeref":0.27305555555555555,"symbol":"circle"},"mode":"markers","name":"ANALGESICS","orientation":"v","showlegend":true,"x":[176],"xaxis":"x","y":[868.59],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>COMMODITY_DESC=ANTACIDS<br>QUANTITY=%{x}<br>SALES_VALUE=%{y}<br>HOUSEHOLDS=%{marker.size}<extra></extra>","hovertext":["ANTACIDS"],"legendgroup":"ANTACIDS","marker":{"color":"#9467BD","size":[56],"sizemode":"area","sizeref":0.27305555555555555,"symbol":"circle"},"mode":"markers","name":"ANTACIDS","orientation":"v","showlegend":true,"x":[87],"xaxis":"x","y":[534.31],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>COMMODITY_DESC=APPAREL<br>QUANTITY=%{x}<br>SALES_VALUE=%{y}<br>HOUSEHOLDS=%{marker.size}<extra></extra>","hovertext":["APPAREL"],"legendgroup":"APPAREL","marker":{"color":"#8C564B","size":[19],"sizemode":"area","sizeref":0.27305555555555555,"symbol":"circle"},"mode":"markers","name":"APPAREL","orientation":"v","showlegend":true,"x":[29],"xaxis":"x","y":[139.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>COMMODITY_DESC=APPLES<br>QUANTITY=%{x}<br>SALES_VALUE=%{y}<br>HOUSEHOLDS=%{marker.size}<extra></extra>","hovertext":["APPLES"],"legendgroup":"APPLES","marker":{"color":"#E377C2","size":[301],"sizemode":"area","sizeref":0.27305555555555555,"symbol":"circle"},"mode":"markers","name":"APPLES","orientation":"v","showlegend":true,"x":[553],"xaxis":"x","y":[1379.17],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>COMMODITY_DESC=AUDIO/VIDEO PRODUCTS<br>QUANTITY=%{x}<br>SALES_VALUE=%{y}<br>HOUSEHOLDS=%{marker.size}<extra></extra>","hovertext":["AUDIO/VIDEO PRODUCTS"],"legendgroup":"AUDIO/VIDEO PRODUCTS","marker":{"color":"#7F7F7F","size":[24],"sizemode":" ...

# %% [markdown]
# SOFT DRINKS se distanciam das demais categorias em quantidade, embora estejam no mesmo nível da categoria BEEF em termos de valor de venda.
#
# Conclue-se que SOFT DRINKS são altamente direcionados ao volume, vendem bem por causa do grande número de compras, enquanto a categoria BEEF é obviamente uma mercadoria orientada pelo preço.
#
# Com um tempo maior de análise seria possível utilizar o algoritmo Apriori, e ver se faz sentido, por exemplo, ter produtos de SOFT DRINKS e BEEF próximos um do outro no mercado, para ajudar nas vendas explorando a ideia de produtos que podem ser comprados juntos, e descobrir outras associações.
